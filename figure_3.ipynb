# %%
# Adapted from: cosanlab @ https://github.com/cosanlab/affective_ISRSA/tree/master/code

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

from util import *
import seaborn as sns
import matplotlib.pyplot as plt
import sys

# %%
sys.version
# Out:
# '3.7.11 (default, Jul 27 2021, 07:03:16) \n[Clang 10.0.0 ]'

# %%
SS, SO, OS = load_IMQ_data(score='uvs', rank=False)
ToM = [SS[i]+SO[i]+OS[i] for i in range(24)]
colors = sns.color_palette('Blues', n_colors=68)
cccc = [colors[int(x)-1] for x in ToM]
sns.palplot(colors)
#plt.savefig('./tom_b.pdf', dpi=66)

# %%
import random
import pandas as pd
import numpy as np
import seaborn as sns
import re
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib.pyplot import plot, show, draw, figure, cm
from pylab import *
sns.set_context('talk', font_scale=0.9)


fig = plt.figure(figsize=(10*1.2, 6.18*1.2))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(OS, SO, SS, s=1, c='k')
#ax.set_xlabel('OS')
#ax.set_ylabel('SO')
#ax.set_zlabel('SS')

for i in range(24):
    ax.text(
        OS[i],
        SO[i],
        SS[i],
        str(i+1),
        color="white",
        bbox=dict(facecolor=cccc[i], alpha=1, boxstyle="round,pad=0.3"),
    )
    
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.view_init(*(30, 30))
#plt.show()

#plt.savefig('./tom.pdf', dpi=666)
